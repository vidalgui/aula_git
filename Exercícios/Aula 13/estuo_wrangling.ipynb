# %%
import pandas as pd
import numpy as np 
from datetime import datetime

# %%
df = pd.read_csv("realtor-data.csv")

# %%
df["prev_sold_date"] = pd.to_datetime(df["prev_sold_date"], format="%Y-%m-%d")

# %%
df.sample()
# Out:
#          status  bed  bath  acre_lot          city           state  zip_code  \
# 10770  for_sale  1.0   2.0       NaN  Saint Thomas  Virgin Islands     802.0
#
#        house_size prev_sold_date     price
# 10770       960.0            NaT  435000.0

# %%
df.groupby(["state", "city"])[["price"]].mean()
# Out:
#                                     price
# state          city
# Connecticut    Andover       2.492542e+05
#                Ashford       2.849269e+05
#                Avon          6.070604e+05
#                Barkhamsted   3.752788e+05
#                Berlin        3.484531e+05
# ...                                   ...
# Virgin Islands Frederiksted  7.014767e+05
#                Kingshill     4.578320e+05
#                Saint John    1.003303e+06
#                Saint Thomas  1.169000e+06
# Virginia       Chincoteague  7.500000e+04
#
# [582 rows x 1 columns]

# %%
df2 = pd.DataFrame()
for i in ["Massachusetts", "Rhode Island", "New York"]:
    df_filtrado = df[df["state"] == i]
    df2 = pd.concat([df2, df_filtrado.sample(250)], axis=0)

# %%
df2
# Out:
#          status  bed  bath  acre_lot              city          state  \
# 46033  for_sale  4.0   2.0      0.12       Springfield  Massachusetts
# 93348  for_sale  4.0   3.0      0.59            Oxford  Massachusetts
# 97029  for_sale  4.0   2.0      0.43            Dudley  Massachusetts
# 91814  for_sale  3.0   1.0      3.06            Oakham  Massachusetts
# 48742  for_sale  2.0   1.0      0.40      South Hadley  Massachusetts
# ...         ...  ...   ...       ...               ...            ...
# 62504  for_sale  3.0   2.0      5.01      East Chatham       New York
# 56915  for_sale  2.0   1.0      1.70     Hoosick Falls       New York
# 63869  for_sale  NaN   NaN      0.52       New Lebanon       New York
# 65811  for_sale  NaN   NaN      1.95            Canaan       New York
# 57331  for_sale  3.0   3.0      1.22  Schodack Landing       New York
#
#        zip_code  house_size prev_sold_date     price
# 46033    1109.0      1225.0            NaT  219900.0
# ...
